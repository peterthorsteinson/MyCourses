# %% [markdown]
# # 2012 Workplace Fatalities by State
#
# ```2012_Workplace_Fatalities_by_State.csv```

# %%
import pandas as pd

df = pd.read_csv("./data/2012_Workplace_Fatalities_by_State.csv")
df.head()
# Out:
#                                                State  \
# 0  South Carolina\r\n(33.99882060100049, -81.0453...
# 1  West Virginia\r\n(38.665511497000466, -80.7126...
# 2  Massachusetts\r\n(42.27687306500047, -72.08268...
# 3  Tennessee\r\n(35.680943063000484, -85.77448642...
# 4  Oklahoma\r\n(35.472034350000456, -97.521068454...
#
#    Number of Fatalities, 2012  Rate of Fatalities, 2012  \
# 0                        63.0                       3.5
# 1                        49.0                       6.9
# 2                        44.0                       1.4
# 3                       101.0                       3.8
# 4                        97.0                       6.1
#
#    State Rank, Fatalities 2012  Number of Injuries/Illnesses 2012  \
# 0                         25.0                            36200.0
# 1                         46.0                            19800.0
# 2                          1.0                            69700.0
# ...

# %%
df.columns
# Out:
# Index(['State', 'Number of Fatalities, 2012', 'Rate of Fatalities, 2012',
#        'State Rank, Fatalities 2012', 'Number of Injuries/Illnesses 2012',
#        'Injuries/Illnesses 2012 Rate', 'Penalties FY 2013 (Average $)',
#        'Penalties FY 2013 (Rank)', 'Inspectors',
#        'Years to Inspect Each Workplace Once', 'State or Federal Program'],
#       dtype='object')

# %%
df.shape
# Out:
# (54, 11)

# %%
df.isnull().sum(axis=0)
# Out:
# State                                    3
# Number of Fatalities, 2012               3
# Rate of Fatalities, 2012                 3
# State Rank, Fatalities 2012              4
# Number of Injuries/Illnesses 2012       12
# Injuries/Illnesses 2012 Rate            11
# Penalties FY 2013 (Average $)            4
# Penalties FY 2013 (Rank)                 4
# Inspectors                               5
# Years to Inspect Each Workplace Once     4
# State or Federal Program                 4
# dtype: int64

# %%
df = df.dropna()
print(df.isnull().sum(axis=0))
print(df.shape)
# Out:
# State                                   0
# Number of Fatalities, 2012              0
# Rate of Fatalities, 2012                0
# State Rank, Fatalities 2012             0
# Number of Injuries/Illnesses 2012       0
# Injuries/Illnesses 2012 Rate            0
# Penalties FY 2013 (Average $)           0
# Penalties FY 2013 (Rank)                0
# Inspectors                              0
# Years to Inspect Each Workplace Once    0
# State or Federal Program                0
# dtype: int64
# (42, 11)

# %%
df.head()
# Out:
#                                                State  \
# 0  South Carolina\r\n(33.99882060100049, -81.0453...
# 1  West Virginia\r\n(38.665511497000466, -80.7126...
# 2  Massachusetts\r\n(42.27687306500047, -72.08268...
# 3  Tennessee\r\n(35.680943063000484, -85.77448642...
# 4  Oklahoma\r\n(35.472034350000456, -97.521068454...
#
#    Number of Fatalities, 2012  Rate of Fatalities, 2012  \
# 0                        63.0                       3.5
# 1                        49.0                       6.9
# 2                        44.0                       1.4
# 3                       101.0                       3.8
# 4                        97.0                       6.1
#
#    State Rank, Fatalities 2012  Number of Injuries/Illnesses 2012  \
# 0                         25.0                            36200.0
# 1                         46.0                            19800.0
# 2                          1.0                            69700.0
# ...

# %%
df.mean()
# Out:
# Number of Fatalities, 2012                 98.023810
# Rate of Fatalities, 2012                    4.123810
# State Rank, Fatalities 2012                25.214286
# Number of Injuries/Illnesses 2012       64178.571429
# Injuries/Illnesses 2012 Rate                3.626190
# Penalties FY 2013 (Average $)            1673.880952
# Penalties FY 2013 (Rank)                   26.666667
# Inspectors                                 42.309524
# Years to Inspect Each Workplace Once      113.333333
# dtype: float64

# %%
df.std()
# Out:
# Number of Fatalities, 2012                 95.465608
# Rate of Fatalities, 2012                    2.072210
# State Rank, Fatalities 2012                14.155126
# Number of Injuries/Illnesses 2012       61912.808619
# Injuries/Illnesses 2012 Rate                0.717740
# Penalties FY 2013 (Average $)            1021.082142
# Penalties FY 2013 (Rank)                   14.800571
# Inspectors                                 40.103821
# Years to Inspect Each Workplace Once       46.046989
# dtype: float64

# %%
df.describe()
# Out:
#        Number of Fatalities, 2012  Rate of Fatalities, 2012  \
# count                   42.000000                  42.00000
# mean                    98.023810                   4.12381
# std                     95.465608                   2.07221
# min                     11.000000                   1.40000
# 25%                     42.250000                   2.60000
# 50%                     74.000000                   3.50000
# 75%                    114.750000                   4.87500
# max                    536.000000                  12.20000
#
#        State Rank, Fatalities 2012  Number of Injuries/Illnesses 2012  \
# count                    42.000000                          42.000000
# mean                     25.214286                       64178.571429
# std                      14.155126                       61912.808619
# min                       1.000000                        6500.000000
# 25%                      12.000000                       26875.000000
# ...

# %%
# %matplotlib inline

from pandas.plotting import scatter_matrix
from matplotlib import pyplot

scatter_matrix(df, figsize=(22, 22))
pyplot.show()

# %%
X = df["Inspectors"]
print(X)
y = df["Number of Injuries/Illnesses 2012"]
print(y)
# Out:
# 0      24.0
# 1       7.0
# 2      33.0
# 3      30.0
# 4      19.0
# 5      74.0
# 6       9.0
# 7       5.0
# 8      20.0
# 9      26.0
# 10     30.0
# 12     48.0
# 13     26.0
# 14     63.0
# 15     39.0
# 16    104.0
# 18      9.0
# 19     57.0
# 21    105.0
# 22     22.0
# 23      8.0
# 24      7.0
# 25      9.0
# 26      9.0
# 27     44.0
# 28     39.0
# 29     48.0
# 30     24.0
# 31     24.0
# 32     75.0
# 34     53.0
# 35      9.0
# 36     58.0
# 37     16.0
# 39    111.0
# 40     36.0
# 42     16.0
# 43     49.0
# 45     11.0
# 46     67.0
# 48     98.0
# 49    216.0
# Name: Inspectors, dtype: float64
# 0      36200.0
# 1      19800.0
# 2      69700.0
# 3      65100.0
# 4      39000.0
# 5     124900.0
# 6      24300.0
# 7       7900.0
# 8      13700.0
# 9      45600.0
# 10     54400.0
# 12     66200.0
# 13     60300.0
# 14    105500.0
# 15     77900.0
# 16     75900.0
# 18     19900.0
# 19    155300.0
# 21    146300.0
# 22     27700.0
# 23     21200.0
# 24     13300.0
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(X, y, 'ro')
plt.xlabel('Inspectors')
plt.ylabel('Number of Injuries/Illnesses 2012')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# Split-out validation dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)

X_train = X_train.values.reshape(-1, 1)
X_test = X_test.values.reshape(-1, 1)
y_train = y_train.values.reshape(-1, 1)
y_test = y_test.values.reshape(-1, 1)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (33,)
# (9,)
# (33,)
# (9,)
# (33, 1)
# (9, 1)
# (33, 1)
# (9, 1)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()  
regressor.fit(X_train, y_train) #training the algorithm
print(regressor.intercept_)
print(regressor.coef_)
# Out:
# [4475.10557122]
# [[1379.878994]]

# %%
# not ver good (Still under construction!!!!!!!!!!!!!!!!!!!!!)
y_pred = regressor.predict(X_test)
df = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_pred.flatten()})
print(df)
# Out:
#      Actual     Predicted
# 0  113600.0  77608.692253
# 1   30600.0  26553.169475
# 2   41200.0  37592.201427
# 3   39000.0  30692.806457
# 4   54400.0  45871.475391
# 5   48900.0  58290.386337
# 6   43800.0  37592.201427
# 7   66200.0  70709.297283
# 8   74800.0  72089.176277
