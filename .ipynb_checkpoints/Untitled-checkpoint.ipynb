# %%
import pandas as pd

players_csv   = "https://raw.githubusercontent.com/chadwickbureau/baseballdatabank/master/core/People.csv"
batting_csv   = "https://raw.githubusercontent.com/chadwickbureau/baseballdatabank/master/core/Batting.csv"

players  = pd.read_csv(players_csv)
batting  = pd.read_csv(batting_csv)

display(players.head())
display(batting.head())
# Out:
#     playerID  birthYear  birthMonth  birthDay birthCountry birthState  \
# 0  aardsda01     1981.0        12.0      27.0          USA         CO
# 1  aaronha01     1934.0         2.0       5.0          USA         AL
# 2  aaronto01     1939.0         8.0       5.0          USA         AL
# 3   aasedo01     1954.0         9.0       8.0          USA         CA
# 4   abadan01     1972.0         8.0      25.0          USA         FL
#
#     birthCity  deathYear  deathMonth  deathDay    ...     nameLast  \
# 0      Denver        NaN         NaN       NaN    ...      Aardsma
# 1      Mobile        NaN         NaN       NaN    ...        Aaron
# 2      Mobile     1984.0         8.0      16.0    ...        Aaron
# 3      Orange        NaN         NaN       NaN    ...         Aase
# 4  Palm Beach        NaN         NaN       NaN    ...         Abad
#
#         nameGiven weight height bats throws       debut   finalGame   retroID  \
# ...

# %%
print(players['playerID'].nunique())  # number of unique playerID in players
print(len(players['playerID']))       # number of rows in players
print(batting['playerID'].nunique())  # number of unique playerID in bating
print(len(batting['playerID']))       # number of rows in batting
# Out:
# 19973
# 19973
# 19689
# 107429

# %%
player_and_batting = pd.merge(batting, players, on='playerID')
display(player_and_batting.head())
# Out:
#     playerID  yearID  stint teamID lgID   G   AB   R   H  2B    ...      \
# 0  abercda01    1871      1    TRO  NaN   1    4   0   0   0    ...
# 1   addybo01    1871      1    RC1  NaN  25  118  30  32   6    ...
# 2   addybo01    1873      1    PH2  NaN  10   51  12  16   1    ...
# 3   addybo01    1873      2    BS1  NaN  31  152  37  54   6    ...
# 4   addybo01    1874      1    HR1  NaN  50  213  25  51   9    ...
#
#       nameLast          nameGiven  weight  height  bats  throws       debut  \
# 0  Abercrombie  Francis Patterson     NaN     NaN   NaN     NaN  1871-10-21
# 1         Addy      Robert Edward   160.0    68.0     L       L  1871-05-06
# 2         Addy      Robert Edward   160.0    68.0     L       L  1871-05-06
# 3         Addy      Robert Edward   160.0    68.0     L       L  1871-05-06
# 4         Addy      Robert Edward   160.0    68.0     L       L  1871-05-06
#
#     finalGame   retroID    bbrefID
# 0  1871-10-21  aberd101  abercda01
# ...
